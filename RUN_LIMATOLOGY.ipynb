# %% [markdown]
# ## Welcome to this SAC-SMA

# %% [markdown]
# ### Note
# The camels data expected (--data_path) requires a bit of re-structuration from the original raw download. It should lead directly the following subfolders: basin_mean_forcing/, usgs_streamflow/, ......, and sacsma_output/
#
# The sacsma_output/ should be like sacsma_output/{SOURCE}/{REGION}/bbbbbbbb_ss_model_****.txt. Example, *sacsma_output/maurer/01/01013500_05_model_output.txt*

# %%
# adapt these arguments and run the line after
period = "19900101,19900120"  # adapt to "20060720,20080820"
camels_root = r"Y:\repo_egu24\data\camels_us"  # Adapt to your reality
path_to = "test_old_period" #r"Y:\repo_egu24\outputs\test_sacsma_runs" # Adapt to your reality

# %%
# Run me
for hp in [1, 2]:
    # !python run_multi.py --hp {hp} --period {period} --forcing_src maurer --n_sub 5 --basin_list 01052500 01350140 --path_to {path_to} --data_path {camels_root}
    # !python run_multi.py --hp {hp} --period {period} --forcing_src maurer --n_sub 5 --sample_basins 2 --path_to {path_to} --data_path {camels_root}
# Out:
# ^C
# ^C

# %% [markdown]
# ### Arguments for the present study
# Convert to code, adapt and run

# %% [raw]
# # adapt these arguments and run the line after
# period = "20060720,20080820"  # adapt to "20060720,20080820"
# camels_root = r"Y:\repo_egu24\data\camels_us"  # Adapt to your reality
# path_to = r"Y:\repo_egu24\outputs\test_sacsma_runs" # Adapt to your reality
# n_sub = 8  # based on the number of CPU to use, fix this according to the capacity of your machine

# %% [raw]
# # Run me
# for hp in [1, 3, 7]:
#     !python run_multi.py --hp {hp} --period {period} --forcing_src maurer --n_sub {n_sub} --sample_basins 56 --path_to {path_to} --data_path {camels_root}
